# %% [markdown]
# ## Importy

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Pobranie zdjęcia z Internetu

# %%
# !wget https://static.boredpanda.com/blog/wp-content/uploads/2020/03/cute-black-cats-3-5e689250cdb2e__700.jpg
# Out:
# --2024-03-17 13:38:38--  https://static.boredpanda.com/blog/wp-content/uploads/2020/03/cute-black-cats-3-5e689250cdb2e__700.jpg
# Resolving static.boredpanda.com (static.boredpanda.com)... 13.249.39.113, 13.249.39.9, 13.249.39.53, ...
# Connecting to static.boredpanda.com (static.boredpanda.com)|13.249.39.113|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.boredpanda.com/blog/wp-content/uploads/2020/03/cute-black-cats-3-5e689250cdb2e__700.jpg [following]
# --2024-03-17 13:38:38--  https://www.boredpanda.com/blog/wp-content/uploads/2020/03/cute-black-cats-3-5e689250cdb2e__700.jpg
# Resolving www.boredpanda.com (www.boredpanda.com)... 99.84.191.112, 99.84.191.111, 99.84.191.85, ...
# Connecting to www.boredpanda.com (www.boredpanda.com)|99.84.191.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 169230 (165K) [image/jpeg]
# Saving to: ‘cute-black-cats-3-5e689250cdb2e__700.jpg’
#
# ...

# %% [markdown]
# ## Załadowanie zdjęcia do pamięci komputera

# %%
foto = plt.imread('/content/cute-black-cats-3-5e689250cdb2e__700.jpg')

# %% [markdown]
# #### **Zad. 1** Wydrukuj zdjęcie. Czy takiego rezultatu się spodziewałeś/spodziewałaś?

# %%
### TWÓJ KOD TUTAJ ###

# %% [markdown]
# #### **Zad. 2.** Sprawdź, jaki jest typ zmiennej `foto`. Wskazówka: funkcja `type`

# %%
### TWÓJ KOD TUTAJ ###

# %% [markdown]
# #### **Zad. 3.** Sprawdź, jaki kształt (rozmiar) ma załadowane zdjęcie. Co oznaczają te liczby? Wskazówka: atrybut `shape`.

# %%
### TWÓJ KOD TUTAJ ###

# %% [markdown]
# #### **Zad. 4.** Sprawdź, z ilu elementów składa się zdjęcie (ile liczb jest zapisanych w zdjęciu). Jaki jest związek między otrzymaną liczbą a liczbami otrzymanymi w poprzednim zadaniu? Wskazówka: atrybut `size`

# %%
### TWÓJ KOD TUTAJ ###
# Out:
# 1522500

# %% [markdown]
# #### **Zad. 5.** Sprawdź, jaki jest największa liczba zawarta w zmiennej `foto`. Wskazówka: funkcja `max`.

# %%
### TWÓJ KOD TUTAJ ###

# %% [markdown]
# #### **Zad. 6.** Sprawdź, jaki jest najmniejsza liczba zawarta w zmiennej `foto`. Wskazówka: funkcja `min`.

# %%
### TWÓJ KOD TUTAJ ###

# %% [markdown]
# #### **Zad. 7.** Przeczytaj artykuł o tym jak reprezentowane są zdjęcia w komputerze. Link: https://www.ledkia.com/blog/pl/what-does-rgb-mean/

# %% [markdown]
# #### **Zad. 8.** Wyświetl zdjęcie. Wskazówka: użyj funkcji `imshow` zawartej w bibliotece `matplotlib`

# %%
### TWÓJ KOD TUTAJ ###
plt.axis('off')
plt.show()

# %% [markdown]
# #### **Zad. 9.** Wyświetl tylko czerwoną warstwę zdjęcia odpowiednio indeksując zmienną `foto`

# %%
plt.imshow(foto[### TWÓJ KOD TUTAJ ###], cmap = "Reds")
plt.title("Warstwa czerwona")
plt.axis('off')
plt.show()

# %% [markdown]
# #### **Zad. 10.** Wyświetl tylko zieloną warstwę zdjęcia odpowiednio indeksując zmienną `foto`

# %%
plt.imshow(foto[### TWÓJ KOD TUTAJ ###], cmap = "Greens")
plt.title("Warstwa zielona")
plt.axis('off')
plt.show()

# %% [markdown]
# #### **Zad. 11.** Wyświetl tylko niebieską warstwę zdjęcia odpowiednio indeksując zmienną `foto`

# %%
plt.imshow(foto[### TWÓJ KOD TUTAJ ###], cmap = "Blues")
plt.title("Warstwa niebieska")
plt.axis('off')
plt.show()

# %% [markdown]
# #### **Zad. 12**. Wytnij ze zdjęcia warstwę czerwoną, a zieloną i niebieską zostaw bez zmian. Wyświetl zdjęcie.

# %%
# Modyfikujemy kopię zdjęcia
foto_no_red = foto.copy()

foto_no_red[### TWÓJ KOD TUTAJ ###] = ### TWÓJ KOD TUTAJ ###

plt.imshow(foto_no_red)
plt.title("Zdjęcie bez czerwonego")
plt.axis('off')
plt.show()

# %% [markdown]
# #### **Zad. 13**. Wytnij ze zdjęcia warstwę zieloną, a czerwoną i niebieską zostaw bez zmian. Wyświetl zdjęcie.

# %%
# Modyfikujemy kopię zdjęcia
foto_no_green = foto.copy()

foto_no_green[### TWÓJ KOD TUTAJ ###] = ### TWÓJ KOD TUTAJ ###

plt.imshow(foto_no_green)
plt.title("Zdjęcie bez zielonego")
plt.axis('off')
plt.show()

# %% [markdown]
# #### **Zad. 14**. Wytnij ze zdjęcia warstwę niebieską, a czerwoną i zieloną zostaw bez zmian. Wyświetl zdjęcie.

# %%
# Modyfikujemy kopię zdjęcia
foto_no_blue = foto.copy()

foto_no_blue[### TWÓJ KOD TUTAJ ###] = ### TWÓJ KOD TUTAJ ###

plt.imshow(foto_no_blue)
plt.title("Zdjęcie bez niebieskiego")
plt.axis('off')
plt.show()

# %% [markdown]
# #### **Zad. 15**. Przyciemnij zdjęcie. Wskazówka: pomnóż zdjęcie przez liczbę mniejszą od 1

# %%
# Modyfikujemy kopię zdjęcia
foto_darker = foto.copy()
# Musimy zmienić typ na float i unormować, żeby móc pomnożyć przez liczbę rzeczywistą
foto_darker = foto_darker.astype(np.float32)/255.

foto_darker = ### TWÓJ KOD TUTAJ ###

plt.imshow(foto_darker)
plt.title("Przyciemnienie")
plt.axis('off')
plt.show()

# %% [markdown]
# #### **Zad. 16**. Rozjaśnij zdjęcie. Wskazówka: pomnóż zdjęcie przez liczbę większą od 1. Uwaga! Po pomnożeniu niektóre wartości mogą być większe niż 1, więc normalnie trzeba by było je przyciąć (patrz funkcja `np.clip`), ale funkcja `imshow` zrobi to za nas

# %%
# Modyfikujemy kopię zdjęcia
foto_brighter = foto.copy()
# Musimy zmienić typ na float i unormować, żeby móc pomnożyć przez liczbę rzeczywistą
foto_brighter = foto_brighter.astype(np.float32)/255.

foto_brighter = ### TWÓJ KOD TUTAJ ###

plt.imshow(foto_brighter)
plt.title("Rozjaśnienie")
plt.axis('off')
plt.show()

# %% [markdown]
# #### **Zad. 17**. Jak wiadomo - wszystkie koty są szare. Napraw zdjęcie, kolorując kota na szaro. Pamiętaj, że kolor szary jest równą mieszanką pozostałych kolorów. Wskazówka: najpierw wybierz ze zdjęcia wszystkie piksele, które mają **jednocześnie** mało czerwonego, mało zielonego, mało niebieskiego - wynik zapisz w zmiennej `mask`.

# %%
# Modyfikujemy kopię zdjęcia
foto_fixed = foto.copy()

# Zmienna mask jest koniunkcją 3 warunków (operator &). Patrz wskazówka do zadania
mask = ### TWÓJ KOD TUTAJ ### & ### TWÓJ KOD TUTAJ ### & ### TWÓJ KOD TUTAJ ###

foto_fixed[mask] = ### TWÓJ KOD TUTAJ ###

plt.imshow(foto_fixed)
plt.title("Naprawiony kot")
plt.axis('off')
plt.show()

# %% [markdown]
# #### **Zad. 18**. Pokoloruj dmuchawce na różowo. Wybierz jeden z odcieni z : https://htmlcolorcodes.com/colors/shades-of-pink/. Wskazówka: na podstawie poprzedniego zadania zastanów się, jak wybrać ze zdjęcia wszystkie białe piksele.

# %%
# Modyfikujemy kopię zdjęcia
foto_dandelion = foto.copy()
mask = ### TWÓJ KOD TUTAJ ###

foto_dandelion[mask, 0] = ### TWÓJ KOD TUTAJ ###
foto_dandelion[mask, 1] = ### TWÓJ KOD TUTAJ ###
foto_dandelion[mask, 2] = ### TWÓJ KOD TUTAJ ###

plt.imshow(foto_dandelion)
plt.title("Kolorowe dmuchawce")
plt.axis('off')
plt.show()
